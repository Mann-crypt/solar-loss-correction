# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
from sklearn.linear_model import LinearRegression
from sklearn.cluster import DBSCAN

# %%
file_path = r"\\172.16.0.126\raaa shared\1. RAAA - SOLAR\Manjot\Model_Performance\Training Data\Chouraniye Juniper_April.xlsx"

# %%
Power_Availbility = 100

# %%
df = pd.read_excel(file_path, sheet_name="Sheet1")
df[df.select_dtypes(include=['number']).columns] = df.select_dtypes(include=['number']).clip(lower=0)
df.fillna(0, inplace=True)
days = int(len(df)/96)

# %%
#Constant Values Zero
df = df.copy()

for col in df.columns:
    s = df[col]

    if not pd.api.types.is_numeric_dtype(s):
        continue

    group = (s != s.shift()).cumsum()
    group_size = group.map(group.value_counts())

    df[col] = s.mask((group_size > 2) & (s != 0), 0)

raw_x = np.array(df['GHI'])
df.head(5)
# Out:
#         Date Time Block   GHI  Power
# 0 2025-04-01   00:00:00  0.11    0.0
# 1 2025-04-01   00:15:00  0.04    0.0
# 2 2025-04-01   00:30:00  0.01    0.0
# 3 2025-04-01   00:45:00  0.00    0.0
# 4 2025-04-01   01:00:00  0.00    0.0

# %%
BLOCKS = 96

for start in range(0, len(df), BLOCKS): 
    
    end = start + BLOCKS 
    
    ghi = df.iloc[start:end]["GHI"].values 
    
    power = df.iloc[start:end]["Power"].values.astype(float) 
    
    ratio = np.divide( power, ghi, out=np.zeros_like(power), where=ghi > 50 ) 
    
    median_ratio = np.median(ratio[ghi > 100]) 
    
    bad = ( (ghi > 250) & (ratio < 0.92 * median_ratio) ) 
    
    power[bad] = 0 
    
    df.iloc[start:end, df.columns.get_loc("Power")] = power

# %%
df.loc[df['GHI'] <= 0, 'Power'] = 0
df.loc[df['Power'] <= 0, 'GHI'] = 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2880 non-null   datetime64[ns]
#  1   Time Block  2880 non-null   object
#  2   GHI         2880 non-null   float64
#  3   Power       2880 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 90.1+ KB

# %%
x = np.array(df['GHI']).reshape(-1, 1)
y = np.array(df['Power']/1000).reshape(-1, 1)

X = np.column_stack((x,y))

# Standardize first
from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(X)

db = DBSCAN(eps=0.3, min_samples=10)
labels = db.fit_predict(X_scaled)

mask = labels != -1

x = x[mask]
y = y[mask]
len(y)
# Out:
# 2874

# %%
import os
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error

# ---------- INPUT ----------
x = np.array(x).flatten()
y = np.array(y).flatten()
weights = 0.1 + 0.9 * (x.flatten() / x.max())**2

# ---------- CLEAN ----------
data = pd.DataFrame({'x': x, 'y': y}).fillna(0)
x = data['x'].values
y = data['y'].values

results = {}

# ---------- SAFE MAPE FUNCTION ----------
def safe_mape(y_true, y_pred):
    mask = y_true != 0
    return mean_absolute_percentage_error(y_true[mask], y_pred[mask])

# ---------- 1. LINEAR ----------
model = LinearRegression()
model.fit(x.reshape(-1,1), y)
y_pred_linear = model.predict(x.reshape(-1,1))

results["Linear"] = {
    "model" : model,
    "r2": r2_score(y, y_pred_linear),
    "type" : "linear",
    "mae": mean_absolute_error(y, y_pred_linear),
    "mape": safe_mape(y, y_pred_linear),
    "x": x,
    "y_pred": y_pred_linear
}

# ---------- 2. POLY 2 ----------
poly2 = np.poly1d(np.polyfit(x, y, 2, w=weights))
y_pred_poly2 = poly2(x)

results["Poly 2"] = {
    "model" : poly2,
    "r2": r2_score(y, y_pred_poly2),
    "type" : "poly",
    "mae": mean_absolute_error(y, y_pred_poly2),
    "mape": safe_mape(y, y_pred_poly2),
    "x": x,
    "y_pred": y_pred_poly2
}

# ---------- 3. POLY 3 ----------
poly3 = np.poly1d(np.polyfit(x, y, 3, w=weights))
y_pred_poly3 = poly3(x)

results["Poly 3"] = {
    "model" : poly3,
    "r2": r2_score(y, y_pred_poly3),
    "type" : "poly",
    "mae": mean_absolute_error(y, y_pred_poly3),
    "mape": safe_mape(y, y_pred_poly3),
    "x": x,
    "y_pred": y_pred_poly3
}

# ---------- PRINT METRICS ----------
print("\nMODEL COMPARISON:\n")
for name, metrics in results.items():
    print(f"{name}: R²={metrics['r2']:.4f}, "
          f"MAE={metrics['mae']:.4f}, "
          f"MAPE={metrics['mape']*100:.2f}%")

# ---------- NORMALIZATION VALUES ----------
MAE_values = [results[name]['mae'] for name in results]
MAPE_values = [results[name]['mape'] for name in results]

# ---------- SCORING FUNCTION ----------
def score_model(m):
    return (
        m['r2']
        - (m['mae'] / max(MAE_values)) * 0.5
        - (m['mape'] / max(MAPE_values)) * 0.5
    )

# ---------- BEST MODEL ----------
best_model_name, best_metrics = max(
    results.items(),
    key=lambda item: score_model(item[1])
)

best_pred = best_metrics["y_pred"]
best_x = best_metrics["x"]

best_model = best_metrics["model"]
best_type = best_metrics["type"]

print(f"\nBest Model: {best_model_name}")

# ---------- ADD BEST PREDICTION ----------
data["Best_Prediction"] = best_pred

# ---------- BAR PLOT FUNCTION ----------
def plot_bar(values, title, ylabel, is_percent=False):
    plt.figure(figsize=(6,4))
    bars = plt.bar(model_names, values)

    for i, name in enumerate(model_names):
        if name == best_model_name:
            bars[i].set_linewidth(3)

    for i, v in enumerate(values):
        label = f"{v*100:.2f}%" if is_percent else f"{v:.3f}"
        plt.text(i, v + 0.01, label, ha='center')

    plt.style.use('seaborn-v0_8')
    plt.xticks(rotation=45)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid(axis='y')
    plt.show()

# ---------- PLOT METRICS ----------
model_names = list(results.keys())

r2_values = [results[name]['r2'] for name in model_names]
mae_values = [results[name]['mae'] for name in model_names]
mape_values = [results[name]['mape'] for name in model_names]

plot_bar(r2_values, "R² Comparison", "R²")
plot_bar(mae_values, "MAE Comparison", "MAE")
plot_bar(mape_values, "MAPE Comparison", "MAPE (%)", is_percent=True)

# ---------- PLOT ALL MODELS ----------
for name, metrics in results.items():

    x_vals = metrics["x"]
    y_vals = metrics["y_pred"]
    score = metrics["r2"]

    plt.figure(figsize=(10,6))
    plt.scatter(x, y, alpha=0.5, label="Original Data")

    sorted_idx = np.argsort(x_vals)

    if name == best_model_name:
        plt.plot(x_vals[sorted_idx], y_vals[sorted_idx],
                 linewidth=2, linestyle='--', color="yellow",
                 label=f"{name} (BEST, R²={score:.3f})")
    else:
        plt.plot(x_vals[sorted_idx], y_vals[sorted_idx],
                 linewidth=2, color="yellow",
                 label=f"{name} (R²={score:.3f})")

    plt.legend()
    plt.xlabel("GHI")
    plt.ylabel("Power")
    plt.title(f"{name} Trendline")
    plt.grid(True)
    plt.show()
# Out:
# MODEL COMPARISON:
#
# Linear: R²=0.9960, MAE=2.1946, MAPE=25.03%
# Poly 2: R²=0.9958, MAE=3.2277, MAPE=38.51%
# Poly 3: R²=0.9984, MAE=1.2997, MAPE=18.08%
#
# Best Model: Poly 3

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_absolute_percentage_error
)
import statsmodels.api as sm
import pandas as pd

results = []

for degree in [1, 2, 3]:

    poly = PolynomialFeatures(degree=degree, include_bias=False)

    X = poly.fit_transform(x.reshape(-1,1))
    X = sm.add_constant(X)

    model = sm.OLS(y, X).fit()

    y_pred = model.predict(X)

    results.append({
        "Degree": degree,
        "R2": r2_score(y, y_pred),
        "Adj_R2": model.rsquared_adj,
        "MAE": mean_absolute_error(y, y_pred),
        "MAPE": mean_absolute_percentage_error(y[y!=0], y_pred[y!=0]),
        "AIC": model.aic,
        "BIC": model.bic
    })

    print("="*80)
    print(f"POLYNOMIAL DEGREE {degree}")
    print("="*80)
    print(model.summary())
    print()

comparison = pd.DataFrame(results)

print("\nComparison:")
print(comparison)

best = comparison.loc[comparison["AIC"].idxmin()]

print(f"Best polynomial degree according to AIC: {best['Degree']}")
# Out:
# ================================================================================
# POLYNOMIAL DEGREE 1
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 7.139e+05
# Date:                Fri, 17 Jul 2026   Prob (F-statistic):               0.00
# Time:                        18:25:59   Log-Likelihood:                -7901.1
# No. Observations:                2874   AIC:                         1.581e+04
# Df Residuals:                    2872   BIC:                         1.582e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4344      0.089      4.864      0.000       0.259       0.610
# x1             0.1614      0.000    844.924      0.000       0.161       0.162
# ==============================================================================
# Omnibus:                      907.293   Durbin-Watson:                   0.453
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            42475.103
# Skew:                           0.735   Prob(JB):                         0.00
# Kurtosis:                      21.776   Cond. No.                         592.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
# POLYNOMIAL DEGREE 2
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 5.759e+05
# Date:                Fri, 17 Jul 2026   Prob (F-statistic):               0.00
# Time:                        18:25:59   Log-Likelihood:                -7215.4
# No. Observations:                2874   AIC:                         1.444e+04
# Df Residuals:                    2871   BIC:                         1.445e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5553      0.074     -7.481      0.000      -0.701      -0.410
# x1             0.1871      0.001    296.422      0.000       0.186       0.188
# x2         -2.914e-05   6.95e-07    -41.901      0.000   -3.05e-05   -2.78e-05
# ==============================================================================
# Omnibus:                     1423.917   Durbin-Watson:                   0.539
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           134072.867
# Skew:                           1.419   Prob(JB):                         0.00
# Kurtosis:                      36.340   Cond. No.                     5.34e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ================================================================================
# POLYNOMIAL DEGREE 3
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 6.370e+05
# Date:                Fri, 17 Jul 2026   Prob (F-statistic):               0.00
# Time:                        18:25:59   Log-Likelihood:                -6488.7
# No. Observations:                2874   AIC:                         1.299e+04
# Df Residuals:                    2870   BIC:                         1.301e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0201      0.059     -0.342      0.733      -0.136       0.095
# x1             0.1399      0.001    117.461      0.000       0.138       0.142
# x2             0.0001   3.32e-06     34.109      0.000       0.000       0.000
# x3         -9.922e-08   2.28e-09    -43.460      0.000   -1.04e-07   -9.47e-08
# ==============================================================================
# Omnibus:                     2119.450   Durbin-Watson:                   0.671
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           576049.266
# Skew:                           2.439   Prob(JB):                         0.00
# Kurtosis:                      72.186   Cond. No.                     4.96e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.96e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Comparison:
#    Degree        R2    Adj_R2       MAE      MAPE           AIC           BIC
# 0       1  0.995993  0.995992  2.194635  0.250348  15806.207282  15818.134202
# 1       2  0.997514  0.997512  1.804726  0.120150  14436.769047  14454.659427
# 2       3  0.998500  0.998499  1.010393  0.125155  12985.475781  13009.329621
# Best polynomial degree according to AIC: 3.0

# %%
comparison["R2_norm"] = comparison["R2"] / comparison["R2"].max()

comparison["AdjR2_norm"] = (
    comparison["Adj_R2"] / comparison["Adj_R2"].max()
)

comparison["MAE_norm"] = 1 - (
    comparison["MAE"] / comparison["MAE"].max()
)

comparison["MAPE_norm"] = 1 - (
    comparison["MAPE"] / comparison["MAPE"].max()
)

comparison["AIC_norm"] = 1 - (
    (comparison["AIC"] - comparison["AIC"].min()) /
    (comparison["AIC"].max() - comparison["AIC"].min())
)

comparison["BIC_norm"] = 1 - (
    (comparison["BIC"] - comparison["BIC"].min()) /
    (comparison["BIC"].max() - comparison["BIC"].min())
)

comparison["Score"] = (
      0.25 * comparison["R2_norm"]
    + 0.25 * comparison["AdjR2_norm"]
    + 0.20 * comparison["MAE_norm"]
    + 0.20 * comparison["MAPE_norm"]
    + 0.05 * comparison["AIC_norm"]
    + 0.05 * comparison["BIC_norm"]
)

comparison = comparison.sort_values("Score", ascending=False)

print(comparison)

best_degree = int(comparison.iloc[0]["Degree"])

print(f"\nBest Polynomial Degree: {best_degree}")
# Out:
#    Degree        R2    Adj_R2       MAE      MAPE           AIC           BIC  \
# 2       3  0.998500  0.998499  1.010393  0.125155  12985.475781  13009.329621
# 1       2  0.997514  0.997512  1.804726  0.120150  14436.769047  14454.659427
# 0       1  0.995993  0.995992  2.194635  0.250348  15806.207282  15818.134202
#
#     R2_norm  AdjR2_norm  MAE_norm  MAPE_norm  AIC_norm  BIC_norm     Score
# 2  1.000000    1.000000  0.539608   0.500077   1.00000  1.000000  0.807937
# 1  0.999012    0.999012  0.177665   0.520069   0.48549  0.485429  0.687599
# 0  0.997489    0.997489  0.000000   0.000000   0.00000  0.000000  0.498744
#
# Best Polynomial Degree: 3

# %%
df2 = pd.read_excel(file_path, sheet_name="SD")
df2[df2.select_dtypes(include=['number']).columns] = df2.select_dtypes(include=['number']).clip(lower=0)
df2.fillna(0, inplace=True)
day = int(len(df2)/96)

# %%
df2.head()
print((df['Power']/1000).max(),
(df['GHI']).max(),
(df2['F_GHI']).max())
# Out:
# 155.32243 1040.92 1005

# %%
p_f = df2['P_GHI'].values
x_f = df2['F_GHI'].values
print(x_f)
# Out:
# [0 0 0 ... 0 0 0]

# %%
print("GHI :",np.max(x),", P_GHI :",np.max(p_f))
# Out:
# GHI : 1040.92 , P_GHI : 1023

# %%
#rx = x.reshape(days, 96)
#rxf = x_f.reshape(day, 96)

#px = np.percentile(rx, 95, axis=0)
#pxf = np.percentile(rxf, 95, axis=0)

#n_f = x_f * (np.sum(px)/np.sum(pxf)) * 0.97
#dxf = n_f.reshape(day, 96)
#dpxf = np.percentile(dxf, 95, axis=0)

#print("GHI :",(np.max(px)),", F_GHI :",np.max(n_f))
#a = np.arange(0, 96)
#plt.figure(figsize=(15,5))
#plt.xlabel('GHI')
#plt.ylabel('Forecast GHI')
#plt.xlim(10, 96)   # zoom X-axis
#plt.ylim(0, 1100)   # zoom Y-axis
#plt.plot(a, pxf, label="forecasted GHI")
#plt.plot(a, dpxf, label="calc forecasted GHI")
#plt.plot(a, px, label="GHI")
#plt.legend()
#plt.show()

# %%
rx = raw_x.reshape(days, 96)
rxf = p_f.reshape(day, 96)

px = np.percentile(rx, 95, axis=0)
pxf = np.percentile(rxf, 95, axis=0)

factors = np.arange(0.75, 1.251, 0.01)
best_factor = None
least_error = np.inf
for f in factors:
    
    scaled_curve = pxf * f
    
    # Mean Squared Error
    error = np.mean((px - scaled_curve) ** 2)
    
    if error < least_error:
        least_error = error
        best_factor = f

print("Best multiplier:", best_factor)
print("Least error:", least_error)

n_f = x_f * best_factor
dxf = n_f.reshape(day, 96)
dpxf = np.percentile(dxf, 95, axis=0)
print("GHI :",(np.max(px)),", F_GHI :",np.max(x_f))

# Early Start fix
forecast = dpxf
actual = px
forecast_start = np.argmax(forecast > 10)
actual_start = np.argmax(actual > 10)

print(forecast_start, actual_start+8)

def sigmoid(x, center, steepness):
    return 1 / (1 + np.exp(-(x - center) / steepness))

x = np.arange(len(forecast))

least_loss = np.inf
best_center = None
best_steepness = None

# Search region
for center in range(max(0, forecast_start-5), min(48, forecast_start+20)):

    for steepness in np.arange(0.5, 4.25, 0.25):

        weight = sigmoid(x, center, steepness)
        corrected = forecast * weight

        # 1. First-half RMSE
        rmse_half = np.sqrt(
            np.mean((actual[:48] - corrected[:48])**2)
        )

        # 2. Sunrise RMSE (from forecast start to actual start + few intervals)
        sunrise_end = min(actual_start + 8, 48)

        rmse_start = np.sqrt(np.mean((actual[forecast_start:sunrise_end] - corrected[forecast_start:sunrise_end])**2))

        # Combined loss
        loss = 0.7 * rmse_half + 0.3 * rmse_start

        if loss < least_loss:
            least_loss = loss
            best_center = center
            best_steepness = steepness

print("Best Center:", best_center, ", Best Steepness:", best_steepness, ", Least Loss:", least_loss)
weight = sigmoid(x, best_center, best_steepness)
corrected = forecast * weight

print(len(forecast))

a = np.arange(0, 96)
plt.figure(figsize=(15,5))
plt.xlabel('GHI')
plt.ylabel('Forecast GHI')
plt.xlim(10, 96)   # zoom X-axis
plt.ylim(0, 1100)   # zoom Y-axis
plt.plot(a, pxf, label="forecasted GHI")
plt.plot(a, dpxf, label="calc forecasted GHI")
plt.plot(a, corrected, label="corr forecasted GHI")
plt.plot(a, px, label="GHI")
plt.legend()
plt.show()
# Out:
# Best multiplier: 1.0200000000000002
# Least error: 11.558374708333181
# GHI : 1029.156 , F_GHI : 1005
# 26 33
# Best Center: 21 , Best Steepness: 0.5 , Least Loss: 12.849737737502172
# 96

# %%
# Apply correct model
if best_type == "linear":
    forecast_power = best_model.predict(n_f.reshape(-1,1))

elif best_type == "poly":
    forecast_power = best_model(n_f)   # np.poly1d is callable


smooth_ghi = savgol_filter(n_f.flatten(), 3, 2)

factor = n_f.flatten() / np.maximum(smooth_ghi, 1)

forecast_power *= np.clip(factor, 0.5, 1.5)
forecast_power = forecast_power * (Power_Availbility/100) * np.tile(weight, day)
print(forecast_power)
# Out:
# [1.15545756e-19 8.53774077e-19 6.30858455e-18 ... 2.00965839e-01
#  2.00965839e-01 2.00965839e-01]

# %%
a = np.arange(len(n_f))
plt.figure(figsize=(15,5))
plt.xlabel('GHI')
plt.ylabel('Forecast Power')
plt.xlim(10, 900)   # zoom X-axis   # zoom Y-axis
plt.plot(a, forecast_power, label="Power")
plt.plot(a, n_f, label="GHI")
plt.legend()
plt.show()

# %%
data1 = {
    'Forecastef_GHI': n_f,
    'Forecasted_Power': forecast_power
}

df3 = pd.DataFrame(data1)
df3['Forecasted_Power'] = df3['Forecasted_Power'].clip(lower=0)

# %%
data2 = {
    'Forecasted GHI': x_f,
    'Calculated Forecasted GHI' : n_f
}
df4 = pd.DataFrame(data2)
df4 = df4.clip(lower=0)

# %%
with pd.ExcelWriter(file_path, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
    df3.to_excel(writer, sheet_name='Forecast_Power_S')
    df4.to_excel(writer, sheet_name='Forecast_GHI_S')
